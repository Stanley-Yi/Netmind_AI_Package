# %%
from BasicMemoryMechanism import BasicMemoryMechanism

help(BasicMemoryMechanism)
# Out:
# Help on class BasicMemoryMechanism in module BasicMemoryMechanism:
#
# class BasicMemoryMechanism(builtins.object)
#  |  BasicMemoryMechanism(memory_name: str, db_name: str, collection_name: str = None, partition_name: str = 'default', if_partion_level: bool = False, milvus_host: str = 'localhost', milvus_port: int = 19530, milvus_user: str = 'root', milvus_psw: str = 'NetMindMilvusDB', mongo_url: str = 'mongodb://localhost:27017/', storage_engine: str = 'default', num_shards: int = 1, embedding_type: xyz.magics.memory._embedding_setting.EmbeddingTypeEnum.EmbeddingType = <EmbeddingType.OpenAI_text_embedding_ada_002: 1>, metric_type: xyz.magics.memory._embedding_setting.MetricTypeEnum.MetricType = <MetricType.L2: 1>, idx_type: xyz.magics.memory._embedding_setting.IdxTypeEnum.IdxType = <IdxType.IVF_FLAT: 2>, **idx_builder)
#  |
#  |  Methods defined here:
#  |
# ...
